# %%
import pandas as pd

# %%
df.head()
# Out:
#    EmployeeID     Name  Age Department  Salary
# 0           1    Alice   45         HR   54000
# 1           2      Bob   52         IT   78000
# 2           3  Charlie   37    Finance   66000
# 3           4    David   28  Marketing   72000
# 4           5      Eva   41      Sales   85000

# %%
df.head(2)
# Out:
#    EmployeeID   Name  Age Department  Salary
# 0           1  Alice   45         HR   54000
# 1           2    Bob   52         IT   78000

# %%
df.tail()
# Out:
#     EmployeeID   Name  Age Department  Salary
# 10          11  Karen   29         IT   65000
# 11          12    Leo   44    Finance   86000
# 12          13   Mona   33         HR   47000
# 13          14   Nina   51      Sales   88000
# 14          15  Oscar   36  Marketing   56000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  15 non-null     int64
#  1   Name        15 non-null     object
#  2   Age         15 non-null     int64
#  3   Department  15 non-null     object
#  4   Salary      15 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 728.0+ bytes

# %%
df.describe()
# Out:
#        EmployeeID        Age        Salary
# count   15.000000  15.000000     15.000000
# mean     8.000000  39.533333  70200.000000
# std      4.472136   9.125057  16549.492871
# min      1.000000  25.000000  40000.000000
# 25%      4.500000  32.500000  59000.000000
# 50%      8.000000  39.000000  70000.000000
# 75%     11.500000  46.500000  85500.000000
# max     15.000000  53.000000  94000.000000

# %%
df.shape
# Out:
# (15, 5)

# %%
df.columns
# Out:
# Index(['EmployeeID', 'Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
mean_salary = df['Salary'].mean()

# %%
print(mean_salary)
# Out:
# 70200.0

# %%
data = {
    'EmployeeID': range(1, 16),
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace', 'Henry', 'Ivy', 'Jack', 'Karen', 'Leo', 'Mona', 'Nina', 'Oscar'],
    'Age': [45, 52, 37, 28, 41, 53, 32, 25, 48, 39, 29, 44, 33, 51, 36],
    'Department': ['HR', 'IT', 'Finance', 'Marketing', 'Sales', 'IT', 'Finance', 'HR', 'Sales', 'Marketing', 'IT', 'Finance', 'HR', 'Sales', 'Marketing'],
    'Salary': [54000, 78000, 66000, 72000, 85000, 90000, 62000, 40000, 94000, 70000, 65000, 86000, 47000, 88000, 56000]
}

# %%
df = pd.DataFrame(data)
